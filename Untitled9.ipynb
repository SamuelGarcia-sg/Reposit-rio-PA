# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelGarcia-sg/Reposit-rio-PA/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Calculadora

# %%
# Calculadora Simples para Google Colab

print("--- Calculadora Python ---")
print("Operações disponíveis:")
print("1: Soma (+)")
print("2: Subtração (-)")
print("3: Multiplicação (*)")
print("4: Divisão (/)")

# Solicita a escolha do usuário
escolha = input("\nDigite o número da operação (1/2/3/4): ")

# Solicita os valores
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))

# Processamento e Exibição do Resultado
if escolha == '1':
    resultado = num1 + num2
    print(f"\nResultado: {num1} + {num2} = {resultado}")
elif escolha == '2':
    resultado = num1 - num2
    print(f"\nResultado: {num1} - {num2} = {resultado}")
elif escolha == '3':
    resultado = num1 * num2
    print(f"\nResultado: {num1} * {num2} = {resultado}")
elif escolha == '4':
    if num2 != 0:
        resultado = num1 / num2
        print(f"\nResultado: {num1} / {num2} = {resultado}")
    else:
        print("\nErro: Não é possível dividir por zero!")
else:
    print("\nOpção inválida!")
# Out:
# --- Calculadora Python ---
# Operações disponíveis:
# 1: Soma (+)
# 2: Subtração (-)
# 3: Multiplicação (*)
# 4: Divisão (/)
#
# Digite o número da operação (1/2/3/4): 4
# Digite o primeiro número: 4
# Digite o segundo número: 4
#
# Resultado: 4.0 / 4.0 = 1.0
