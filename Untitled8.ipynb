# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelGarcia-sg/Reposit-rio-PA/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Conversão de graus celsius para fahrenheit

# %%
# Programa que converte graus celsius para fahrenheit
celsius = float(input("Digite a temperatura em Celsius: "))
fahrenheit = (celsius * 1.8) + 32

print(f"{celsius}°C equivale a {fahrenheit}°F")
# Out:
# Digite a temperatura em Celsius: 25
# 25.0°C equivale a 77.0°F
